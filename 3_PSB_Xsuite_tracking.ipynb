# %% [markdown]
# # Προσομοιώσεις Πλεγμάτων Επιταχυντών με Python και Xsuite
# # Μάθημα 5ο: Tracking in Xsuite: the CERN Proton Synchrotron Booster
# #### Φυσική των Επιταχυντών
# #### Μεταπτυχιακό Υποατομικής Φυσικής, 2o έτος
# #### Τμήμα Φυσικής / Αριστοτέλειο Πανεπιστήμιο Θεσσαλονίκης
# #### Εαρινό εξάμηνο 2025
#
# *T. Prebibaj, F. Antoniou, F. Asvesta, Y. Papaphilippou*

# %%
# Import xsuite modules and other libraries
import xtrack as xt
import xpart as xp
import xplt

from cpymad.madx import Madx
import numpy as np
import matplotlib.pyplot as plt

import nafflib
from scipy.signal import argrelextrema
from scipy.fftpack import fft

# %% [markdown]
# ## The CERN Proton Synchrotron Booster (PSB)
#
# <p align="center">
# <img src=./images_lectures/psb.png width="40%">
# </p>
#
# - PSB consists of 4 identical, vertically stacked rings with commin injection and extraction lines.
#
# - It accelerates protons from $160$ MeV to $2$ GeV in $1.2$ seconds for high-intensity and high-brightness physics.
#
# - Beam intensities rage from $10^{10}$ to $10^{13}$ protons per ring and the beam emittances from $1$ mm mrad to $15$ mm mrad.

# %% [markdown]
# ### Exercise 19 (guided): load and plot the layout of the PSB
#
# Load the PSB line to Xsuite from the MAD-X sequence and plot it using xplt.

# %%
# The MAD-X sequence is at the psb/psb.seq file. The aperture of each element is defined at psb/psb_aperture.dbx
mad = Madx()
mad.options.echo = False # to not print the stdout of MAD-X  
mad.chdir('psb')
mad.call('psb_flat_bottom.madx') # loads the PSB sequence, aperture, etc. in MAD-X
line= xt.Line.from_madx_sequence(mad.sequence['psb1'],
                                 deferred_expressions=True,
                                 allow_thick=True)
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.08.01  (64 bit, Linux)       +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2022.02.25               +
#   + Execution date: 2024.05.31 15:29:39      +
#   ++++++++++++++++++++++++++++++++++++++++++++
# ++++++ info: seqedit - number of elements installed:  0
# ++++++ info: seqedit - number of elements moved:      0
# ++++++ info: seqedit - number of elements removed:    0
# ++++++ info: seqedit - number of elements replaced:   0
# ++++++ info: seqedit - number of elements installed:  1
# ++++++ info: seqedit - number of elements moved:      0
# ++++++ info: seqedit - number of elements removed:    0
# ++++++ info: seqedit - number of elements replaced:   0
# Converting sequence "psb1":   0%|          | 0/530 [00:00<?, ?it/s]

# %%
# Check elements
line_table = line.get_table()
line_table_df = line_table.to_pandas()
line_table_df[0:20]
# Out:
#            s element_type                name  isthick compound_name
# 0   0.000000       Marker          psb1$start    False
# 1   0.000000       Marker      p01ring1$start    False
# 2   0.000000        Drift             drift_0     True
# 3   0.179500       Marker  bi1.bsw1l1.1_entry    False  bi1.bsw1l1.1
# 4   0.179500   DipoleEdge    bi1.bsw1l1.1_den    False  bi1.bsw1l1.1
# 5   0.179500         Bend        bi1.bsw1l1.1     True  bi1.bsw1l1.1
# 6   0.492500   DipoleEdge    bi1.bsw1l1.1_dex    False  bi1.bsw1l1.1
# 7   0.492500       Marker   bi1.bsw1l1.1_exit    False  bi1.bsw1l1.1
# 8   0.492500        Drift             drift_1     True
# 9   0.869500       Marker  bi1.bsw1l1.2_entry    False  bi1.bsw1l1.2
# 10  0.869500   DipoleEdge    bi1.bsw1l1.2_den    False  bi1.bsw1l1.2
# 11  0.869500         Bend        bi1.bsw1l1.2     True  bi1.bsw1l1.2
# 12  1.194500   DipoleEdge    bi1.bsw1l1.2_dex    False  bi1.bsw1l1.2
# 13  1.194500       Marker   bi1.bsw1l1.2_exit    False  bi1.bsw1l1.2
# 14  1.194500        Drift             drift_2     True
# 15  1.327628       Marker    bi1.btv1l1_entry    False    bi1.btv1l1
# 16  1.327628        Drift          bi1.btv1l1     True    bi1.btv1l1
# 17  1.327628       Marker     bi1.btv1l1_exit    False    bi1.btv1l1
# 18  1.327628        Drift             drift_3     True
# 19  1.334000       Marker   bi1.bcsf1l1_entry    False   bi1.bcsf1l1

# %%
# Get circumference
print('PSB circumference in meters: ', line.get_length())
# Out:
# PSB circumference in meters:  157.07999999999979

# %%
plot = xplt.FloorPlot(line=line, labels="S.Q.", figsize=(8,8))
plot.legend()

# %% [markdown]
# - The PSB ring consists of 16 identical cells with a total circumference of $157.08$ meters (relatively similar with the cases we have seen so far).
#
# - Each cell (or period or sector) consists of one defocusing and two focusing quadrupoles, two dipoles and many higher order magnets (sextupoles, octupoles, etc).

# %% [markdown]
# ### Exercise 20 (guided): optics functions of PSB
#
# Use the line.twiss() method of Xsuite to compute the optics functions around the PSB and plot them.

# %%
# We need to add a reference particle for the twiss calculation (mass, energy)
line.particle_ref=xp.Particles(mass0=xp.PROTON_MASS_EV,gamma0=mad.sequence.psb1.beam.gamma)
print('Reference particle added at gamma0=%s.'%(mad.sequence.psb1.beam.gamma))

line.twiss_default['method'] = '4d' # to ignore the longitudinal plane
twiss = line.twiss()
twiss_df = twiss.to_pandas()
# Out:
# Reference particle added at gamma0=1.1705262269290748.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.

# %%
twiss_df.columns
# Out:
# Index(['name', 's', 'x', 'px', 'y', 'py', 'zeta', 'delta', 'ptau', 'W_matrix',
#        'betx', 'bety', 'alfx', 'alfy', 'gamx', 'gamy', 'dx', 'dpx', 'dy',
#        'dpy', 'dx_zeta', 'dy_zeta', 'betx1', 'bety1', 'betx2', 'bety2', 'mux',
#        'muy', 'muzeta', 'nux', 'nuy', 'nuzeta', 'dzeta', 'dmux', 'dmuy',
#        'bx_chrom', 'by_chrom', 'ax_chrom', 'ay_chrom', 'wx_chrom', 'wy_chrom'],
#       dtype='object')

# %%
# This is the twiss table
twiss_df[['s', 'betx', 'alfx', 'gamx', 'mux', 'dx', 'bety', 'alfy', 'gamy', 'muy', 'dy']]
# Out:
#              s      betx      alfx      gamx       mux        dx      bety  \
# 0       0.0000  5.632690  0.250691  0.188692  0.000000 -1.311375  4.296431
# 1       0.0000  5.632690  0.250691  0.188692  0.000000 -1.311375  4.296431
# 2       0.0000  5.632690  0.250691  0.188692  0.000000 -1.311375  4.296431
# 3       0.1795  5.548771  0.216821  0.188692  0.005111 -1.311366  4.180877
# 4       0.1795  5.548771  0.216821  0.188692  0.005111 -1.311366  4.180877
# ...        ...       ...       ...       ...       ...       ...       ...
# 1218  157.0800  5.632690  0.318027  0.195491  4.400000 -1.311375  4.296431
# 1219  157.0800  5.632690  0.250691  0.188692  4.400000 -1.311375  4.296431
# 1220  157.0800  5.632690  0.250691  0.188692  4.400000 -1.311375  4.296431
# 1221  157.0800  5.632690  0.250691  0.188692  4.400000 -1.311375  4.296431
# 1222  157.0800  5.632690  0.250691  0.188692  4.400000 -1.311375  4.296431
#
#           alfy      gamy       muy   dy
# 0     0.345255  0.260495  0.000000 -0.0
# 1     0.345255  0.260495  0.000000 -0.0
# 2     0.345255  0.260495  0.000000 -0.0
# 3     0.298496  0.260495  0.006743  0.0
# 4     0.298496  0.260495  0.006743  0.0
# ...        ...       ...       ...  ...
# 1218  0.296161  0.253166  4.450000  0.0
# 1219  0.345255  0.260495  4.450000  0.0
# 1220  0.345255  0.260495  4.450000  0.0
# 1221  0.345255  0.260495  4.450000  0.0
# 1222  0.345255  0.260495  4.450000  0.0
#
# [1223 rows x 11 columns]

# %%
plt.figure(figsize=(15,5))
plt.plot(twiss_df['s'], twiss_df['betx'], label=r'$\beta_x$ [m]', c='blue')
plt.plot(twiss_df['s'], twiss_df['alfx'], label=r'$\alpha_x$', c='red')
plt.plot(twiss_df['s'], twiss_df['bety'], label=r'$\beta_y$ [m]', c='blue', ls='--')
plt.plot(twiss_df['s'], twiss_df['alfy'], label=r'$\alpha_y$', c='red', ls='--')
plt.legend()

# %% [markdown]
# ### Exercise 21 (guided): matching the tunes
#
# In PSB, all the focusing quadrupoles are powered in series which means all of them can have the same strength. Same applies for the defocusing quadrupoles. The strength of the focusing quadrupoles is conventionally named as "kbrqf" while for the defocusing "kbrqd".
#
# Xsuite has algorithms to calculate the quadrupole strengths in order to achieve our desired optics constrains (for example a certain tune, an upper limit for the beta-function etc.). This process is known as optics matching.
#
# In this exercise, vary the quadrupole strength to match the transverse betatron tunes to $(Q_x,Q_y)=(4.17,4.23)$ using the `line.match` command of Xsuite.

# %%
# The initial lattice gives the following tunes
print('Qx = ', twiss.qx)
print('Qy = ', twiss.qy)
# Out:
# Qx =  4.399999999756882
# Qy =  4.450000000567766

# %%
# Here we vary the strength of the quadrupoles (two knobs) to reach the target tunes (two constraints)
# The matching process is not always possible..
line.match(
      vary=[
            xt.Vary('kbrqf', step=1e-8),
            xt.Vary('kbrqd', step=1e-8),
      ],
      targets = [
                  xt.Target('qx', 4.17, tol=1e-5),
                  xt.Target('qy', 4.23, tol=1e-5)
      ]
)
# Out:
# Matching: model call n. 8

# %%
# We re-twiss the latice
twiss_after = line.twiss()
twiss_after_df = twiss_after.to_pandas()
print('Horizontal tune after the matching Qx = ', twiss_after.qx)
print('Vertical tune after the matching Qy = ', twiss_after.qy)
# Out:
# Horizontal tune after the matching Qx =  4.170001792569275
# Vertical tune after the matching Qy =  4.230003706158103

# %%
# The beta-function changed in the new configuration of the quadrupoles
plt.figure(figsize=(15,5))
plt.plot(twiss_df['s'], twiss_df['betx'], label='Before matching')
plt.plot(twiss_after_df['s'], twiss_after_df['betx'], label='After matching')
plt.xlabel('s [m]')
plt.ylabel(r'$\beta_x$ [m]')
plt.legend()

# %% [markdown]
# ### Exercise 22 (guided): tracking in the PSB
#
# - Generate a matched Guassian distribution of $1000$ particles and track it for one turn in the PSB lattice. Plot the particle trajectories along the ring in the vertical plane (y).
#
# - Track the same distribution for $1000$ turns (without saving the particle state at all PSB elements). How long did it take?

# %%
# Xsuite tracks in 3D, so we need to add a voltage to the RF cavity to simulate the longitudinal motion
line.element_refs['br.c02'].voltage = 0.008*1e6
print('Constant voltage = 8 kV added to the dummy RF.')

particles = xp.generate_matched_gaussian_bunch(num_particles=1000,
                                total_intensity_particles=1e10,
                                nemitt_x=1e-6, nemitt_y=1e-6, sigma_z=10,
                                particle_ref=line.particle_ref,
                                line=line
                                )
# Out:
# Constant voltage = 8 kV added to the dummy RF.
# *** Maximum RMS bunch length 24.692096598476212m.
# /home/tprebiba/python_environments/base-2022/miniconda/lib/python3.9/site-packages/scipy/integrate/_quadpack_py.py:1151: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# ... distance to target bunch length: -9.8998e+00
# ... distance to target bunch length: 1.4070e+01
# ... distance to target bunch length: 1.0223e+01
# ... distance to target bunch length: 6.1652e-01
# ... distance to target bunch length: -6.3193e-02
# ... distance to target bunch length: -5.7318e-04
# ... distance to target bunch length: 8.3483e-09
# ... distance to target bunch length: -5.5011e-05
# --> Bunch length: 10.00000000834825
# --> Emittance: 0.23228237555785303

# %%
plot = xplt.PhaseSpacePlot(particles)
plot.fig.tight_layout()

# %%
# Tracking for one turn but saving the particle distribution at all PSB elements
line.track(particles, num_turns=1, turn_by_turn_monitor='ONE_TURN_EBE') # to save in all elements

# %%
# Plotting the particle trajectories in y
plt.figure(figsize=(15,5))
for i in range(1000):
    plt.plot(line.record_last_track.s[0], line.record_last_track.y[i]*1e3, '-', lw=0.1, c='blue')
plt.plot(line.record_last_track.s[0], line.record_last_track.y[0]*1e3, '-', lw=3, c='orange', label='Single particle trajectory')
plt.xlabel('s [m]')
plt.ylabel('y [mm]')
# Out:
# Text(0, 0.5, 'y [mm]')

# %% [markdown]
# > Note: the particle motion in a real accelerator is not that far from the one we saw in Exercise 15.

# %%
import time
start = time.time()
line.track(particles, num_turns=1000)
end = time.time()
print('Tracking time for 1000 turns = ', end-start, ' seconds')
print('Tracking time per turn per particle = ', (end-start)/(1000*1000)*1e6, 'microseconds')
# Out:
# Tracking time for 1000 turns =  9.31875991821289  seconds
# Tracking time per turn per particle =  9.31875991821289 microseconds

# %% [markdown]
# ### Exercise 23 (guided): reconstruct tune from turn-by-turn data
#
# - Match the PSB lattice to the working point of $(Q_x, Q_y)=(4.403, 4.453)$  and track a single particle for 800 turns.
#
# - Do an FFT analysis to calculate the tune from the turn-by-turn data (you can use scipy.fft or NAFFlib)
#
# - Add some noise to the TbT beam position and re-do the FFT.

# %%
# The MAD-X sequence is at the psb/psb.seq file. The aperture of each element is defined at psb/psb_aperture.dbx
mad = Madx()
mad.options.echo = False # to not print the stdout of MAD-X  
mad.chdir('psb')
mad.call('psb_flat_bottom.madx') # loads the PSB sequence, aperture, etc. in MAD-X
line= xt.Line.from_madx_sequence(mad.sequence['psb1'],
                                 deferred_expressions=True,
                                 allow_thick=True)

# We need to add a reference particle for the twiss calculation (mass, energy)
line.particle_ref=xp.Particles(mass0=xp.PROTON_MASS_EV,gamma0=mad.sequence.psb1.beam.gamma)
print('Reference particle added at gamma0=%s.'%(mad.sequence.psb1.beam.gamma))

# Xsuite tracks in 3D, so we need to add a voltage to the RF cavity to simulate the longitudinal motion
line.element_refs['br.c02'].voltage = 0.008*1e6
print('Constant voltage = 8 kV added to the dummy RF.')

Qx0 = 4.403
Qy0 = 4.453
# Here we vary the strength of the quadrupoles (two knobs) to reach the target tunes (two constraints)
# The matching process is not always possible..
line.match(
      vary=[
            xt.Vary('kbrqf', step=1e-8),
            xt.Vary('kbrqd', step=1e-8),
      ],
      targets = [
                  xt.Target('qx', Qx0, tol=1e-5),
                  xt.Target('qy', Qy0, tol=1e-5)
      ]
)

twiss = line.twiss()
twiss_df = twiss.to_pandas()
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.08.01  (64 bit, Linux)       +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2022.02.25               +
#   + Execution date: 2024.05.31 15:33:57      +
#   ++++++++++++++++++++++++++++++++++++++++++++
# ++++++ info: seqedit - number of elements installed:  0
# ++++++ info: seqedit - number of elements moved:      0
# ++++++ info: seqedit - number of elements removed:    0
# ++++++ info: seqedit - number of elements replaced:   0
# ++++++ info: seqedit - number of elements installed:  1
# ++++++ info: seqedit - number of elements moved:      0
# ++++++ info: seqedit - number of elements removed:    0
# ++++++ info: seqedit - number of elements replaced:   0
# Converting sequence "psb1":   0%|          | 0/530 [00:00<?, ?it/s]
# Reference particle added at gamma0=1.1705262269290748.
# Constant voltage = 8 kV added to the dummy RF.
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Matching: model call n. 4

# %%
 # single particle at x=0.5 mm, y=1 mm
particles = line.build_particles(x = [0.5e-3], y=[1e-3])

num_turns = 800
line.track(particles, num_turns=num_turns, turn_by_turn_monitor=True)

x_tbt = line.record_last_track.x[0]
y_tbt = line.record_last_track.y[0]

# %%
# Plotting turn-by-turn data for the two planes
plt.figure(figsize=(10,4))
plt.plot(y_tbt*1e3, linewidth=1, label='y')
plt.plot(x_tbt*1e3, linewidth=1, label='x')
plt.xlabel('Turns')
plt.ylabel('Amplitude [mm]')
plt.legend()

# %%
# spectrum using scipy
data = np.array(y_tbt) # focusing only in the y-plane
N = len(data)
freqs = np.linspace(0,1,N)
ampls = fft(data)
tunes = freqs[:N//2]
norm_ampls = abs(ampls[:N//2])/np.max(abs(ampls))
maximas = argrelextrema(norm_ampls, np.greater)
inds = norm_ampls[maximas].argsort()
max_ampls = norm_ampls[maximas][inds][::-1]
max_tunes = tunes[maximas][inds][::-1]

# spectrum using NAFFlib
norder = 3 # number of the most dominant frequencies
qs, A, B = nafflib.get_tunes(data, norder)

# %%
f,axs = plt.subplots(1,2,figsize=(12,4))
fontsize=15

ax = axs[0]
ax.set_xlabel('Turn nr.', fontsize=fontsize)
ax.set_ylabel('TbT position [mm]', fontsize=fontsize)
ax.tick_params(labelsize=fontsize)
ax.plot(data*1e3, '.', ms=1.0, c='blue')

ax = axs[1]
ax.set_xlabel('Tune', fontsize=fontsize)
ax.set_ylabel('Normalized Amplitude (a.u.)', fontsize=fontsize)
ax.tick_params(labelsize=fontsize)
ax.stem(qs, abs(A/np.max(A)), label='NAFFlib ($q=%1.3f$)'%qs[0])
ax.plot(tunes, norm_ampls, '-', c='red', lw=2.0, label='Scipy fft ($q=%1.3f$)'%max_tunes[0])
ax.plot(max_tunes[0:1], max_ampls[0:1], '*', ms=10, color='green')
ax.legend(loc=0, fontsize=fontsize-3)
ax.set_xlim(0.4,0.5)

f.tight_layout()
plt.show()

# %%
# Adding errors in the turn-by-turn data
data2 = data + 1e-3*np.random.randn(len(data)) # to simulate noise
#data2 = 1.05*data2 # 5 percent calibration error

# spectrum using scipy
N = len(data2)
freqs = np.linspace(0,1,N)
ampls = fft(data2)
tunes = freqs[:N//2]
norm_ampls = abs(ampls[:N//2])/np.max(abs(ampls))
maximas = argrelextrema(norm_ampls, np.greater)
inds = norm_ampls[maximas].argsort()
max_ampls = norm_ampls[maximas][inds][::-1]
max_tunes = tunes[maximas][inds][::-1]

# spectrum using NAFFlib
norder = 3 # number of the most dominant frequencies
qs, A, B = nafflib.get_tunes(data2, norder)

# %%
f,axs = plt.subplots(1,2,figsize=(12,4))
fontsize=15

ax = axs[0]
ax.set_xlabel('Turn nr.', fontsize=fontsize)
ax.set_ylabel('TbT position [mm]', fontsize=fontsize)
ax.tick_params(labelsize=fontsize)
ax.plot(data2*1e3, '.', ms=1.0, c='blue')

ax = axs[1]
ax.set_xlabel('Tune', fontsize=fontsize)
ax.set_ylabel('Normalized Amplitude (a.u.)', fontsize=fontsize)
ax.tick_params(labelsize=fontsize)
ax.plot(tunes, norm_ampls, '-', c='red', lw=1.0, label='Scipy fft ($q=%1.3f$)'%max_tunes[0])
ax.plot(max_tunes[0:1], max_ampls[0:1], '*', ms=10, color='green')
ax.stem(qs, abs(A/np.max(A)), label='NAFFlib ($q=%1.3f$)'%qs[0])
ax.legend(loc=0, fontsize=fontsize-3)
ax.set_xlim(0.4,0.5)

f.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 24 (guided): motion near a quadrupolar resonance - beta-beating
#
# - Match the PSB lattice to the working point of $(Q_x, Q_y)=(4.403, 4.473)$ and save the twiss table.
#
# - Add a quadrupole error (impoerfection) in the lattice. You can do that by power the QNO816 quadrupoles with an integrated strength of 0.0045 (line variable name "kbr1qno816l3").
#
# - Re-twiss and compare the vertical beta functino ('bety') with the initial twiss table. What do you observe?
#
# - Generate a matched Guassian distribution of $1000$ particles and track it for one turn in the PSB lattice. Plot the particle trajectories along the ring in the vertical plane (y). What do you observe?

# %%
# Loading and matching the PSB lattice
mad = Madx()
mad.options.echo = False
mad.chdir('psb')
mad.call('psb_flat_bottom.madx')
line= xt.Line.from_madx_sequence(mad.sequence['psb1'],deferred_expressions=True,allow_thick=True)
line.particle_ref=xp.Particles(mass0=xp.PROTON_MASS_EV,gamma0=mad.sequence.psb1.beam.gamma)
line.element_refs['br.c02'].voltage = 0.008*1e6
Qx0 = 4.403
Qy0 = 4.49
line.match(vary=[xt.Vary('kbrqf', step=1e-8),xt.Vary('kbrqd', step=1e-8)],
           targets = [xt.Target('qx', Qx0, tol=1e-5),xt.Target('qy', Qy0, tol=1e-5)])
line.element_refs['br.c02'].voltage = 0.008*1e6 # for the tracking later
twiss = line.twiss()
twiss_before = twiss.to_pandas()
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.08.01  (64 bit, Linux)       +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2022.02.25               +
#   + Execution date: 2024.05.31 16:05:18      +
#   ++++++++++++++++++++++++++++++++++++++++++++
# ++++++ info: seqedit - number of elements installed:  0
# ++++++ info: seqedit - number of elements moved:      0
# ++++++ info: seqedit - number of elements removed:    0
# ++++++ info: seqedit - number of elements replaced:   0
# ++++++ info: seqedit - number of elements installed:  1
# ++++++ info: seqedit - number of elements moved:      0
# ++++++ info: seqedit - number of elements removed:    0
# ++++++ info: seqedit - number of elements replaced:   0
# Converting sequence "psb1":   0%|          | 0/530 [00:00<?, ?it/s]
# Compiling ContextCpu kernels...
# Done compiling ContextCpu kernels.
# Matching: model call n. 8

# %%
# Assigning the quadrupolar error to the lattice
line.vars['kbr1qno816l3'] = 0.0045

# %%
# Re-twissing after the error
twiss = line.twiss()
twiss_after = twiss.to_pandas()

# %%
# Plotting the beta functions before and after the error
plt.figure(figsize=(15,5))
plt.plot(twiss_before['s'], twiss_before['bety'], label='Before error')
plt.plot(twiss_after['s'], twiss_after['bety'], label='After error')
plt.xlabel('s [m]')
plt.ylabel(r'$\beta_y$ [m]')
plt.legend()

# %% [markdown]
# > Note: the quadrupolar error perturbed the vertical beta-function. This effect is known as beta-beating and is particularly enhanced when the tune is near a half-integer value (here Qy=4.49 close to 4.5).

# %%
# generate matched distribution
particles = xp.generate_matched_gaussian_bunch(num_particles=1000,
                                total_intensity_particles=1e10,
                                nemitt_x=1e-6, nemitt_y=1e-6, sigma_z=10,
                                particle_ref=line.particle_ref,
                                line=line
                                )
# Out:
# *** Maximum RMS bunch length 24.6920965984762m.
# /home/tprebiba/python_environments/base-2022/miniconda/lib/python3.9/site-packages/scipy/integrate/_quadpack_py.py:1151: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# ... distance to target bunch length: -9.8998e+00
# ... distance to target bunch length: 1.4070e+01
# ... distance to target bunch length: 1.0223e+01
# ... distance to target bunch length: 6.1652e-01
# ... distance to target bunch length: -6.3193e-02
# ... distance to target bunch length: -5.7318e-04
# ... distance to target bunch length: 8.3483e-09
# ... distance to target bunch length: -5.5011e-05
# --> Bunch length: 10.000000008348257
# --> Emittance: 0.23119125014066877

# %%
# Tracking for one turn but saving the particle distribution at all PSB elements
line.track(particles, num_turns=1, turn_by_turn_monitor='ONE_TURN_EBE') # to save in all elements

# %%
# Plotting the particle trajectories in y
plt.figure(figsize=(15,5))
for i in range(1000):
    plt.plot(line.record_last_track.s[0], line.record_last_track.y[i]*1e3, '-', lw=0.1, c='blue')
plt.plot(line.record_last_track.s[0], line.record_last_track.y[0]*1e3, '-', lw=3, c='orange', label='Single particle trajectory')
plt.xlabel('s [m]')
plt.ylabel('y [mm]')
# Out:
# Text(0, 0.5, 'y [mm]')

# %% [markdown]
# > Note how perturbed is the motion of the particles in the y-plane after the quadrupolar error.

# %% [markdown]
# ### Exercise 25 (guided): motion on a quadrupolar resonance - phase space
#
# - From the previous example, track a single particle for 800 turns and plot the vertical phase space (**phase space near a resonance**).
#
# - Re-match the lattice at $(Q_x, Q_y)=(4.23, 4.17)$, re-track for 800 turns and plot the same phase space (**phase space far from a resonance**).
#
# - Re-match the lattice at $(Q_x, Q_y)=(4.40, 4.495)$, re-track for 800 turns and plot the same phase space (**phase space on a resonance**).

# %%
# Rematching the tunes to (Qx,Qy) = (4.403,4.49)
line.vars['kbr1qno816l3'] = 0.0
line.match(vary=[xt.Vary('kbrqf', step=1e-8),xt.Vary('kbrqd', step=1e-8)],
           targets = [xt.Target('qx', 4.403, tol=1e-5), xt.Target('qy', 4.49, tol=1e-5)])
line.vars['kbr1qno816l3'] = 0.0045
particles = line.build_particles(x = [0.5e-3], y=[1e-3]) # single particle at x=0.5 mm, y=1 mm
num_turns = 800
line.track(particles, num_turns=num_turns, turn_by_turn_monitor=True)
y_tbt = line.record_last_track.y[0]
py_tbt = line.record_last_track.py[0]
# Out:
# Matching: model call n. 1

# %%
plt.figure(figsize=(6,5))
plt.plot(y_tbt*1e3, py_tbt*1e3, '.', ms=5)
plt.xlabel('y [mm]')
plt.ylabel('py [mrad]')
# Out:
# Text(0, 0.5, 'py [mrad]')

# %% [markdown]
# > Note: phase space near a resonance is stable but perturbed.

# %%
# Rematching the tunes to (Qx,Qy) = (4.17,4.23)
line.vars['kbr1qno816l3'] = 0.0
line.match(vary=[xt.Vary('kbrqf', step=1e-8),xt.Vary('kbrqd', step=1e-8)],
           targets = [xt.Target('qx', 4.17, tol=1e-5), xt.Target('qy', 4.23, tol=1e-5)])
line.vars['kbr1qno816l3'] = 0.0045
# Retracking
particles = line.build_particles(x = [0.5e-3], y=[1e-3]) # single particle at x=0.5 mm, y=1 mm
num_turns = 800
line.track(particles, num_turns=num_turns, turn_by_turn_monitor=True)
y_tbt = line.record_last_track.y[0]
py_tbt = line.record_last_track.py[0]
# Out:
# Matching: model call n. 8

# %%
plt.figure(figsize=(6,5))
plt.plot(y_tbt*1e3, py_tbt*1e3, '.', ms=5)
plt.xlabel('y [mm]')
plt.ylabel('py [mrad]')
# Out:
# Text(0, 0.5, 'py [mrad]')

# %% [markdown]
# > Note: phase space far from the resonance is not pertubed.

# %%
# Rematching the tunes to (Qx,Qy) = (4.403,4.493)
line.vars['kbr1qno816l3'] = 0.0
line.match(vary=[xt.Vary('kbrqf', step=1e-8),xt.Vary('kbrqd', step=1e-8)],
           targets = [xt.Target('qx', 4.403, tol=1e-5), xt.Target('qy', 4.493, tol=1e-5)])
line.vars['kbr1qno816l3'] = 0.0045
# Retracking
particles = line.build_particles(x = [0.5e-3], y=[1e-3]) # single particle at x=0.5 mm, y=1 mm
num_turns = 800
line.track(particles, num_turns=num_turns, turn_by_turn_monitor=True)
y_tbt = line.record_last_track.y[0]
py_tbt = line.record_last_track.py[0]
# Out:
# Matching: model call n. 12

# %%
plt.figure(figsize=(6,5))
plt.plot(y_tbt*1e3, py_tbt*1e3, '.', ms=5)
plt.xlabel('y [mm]')
plt.ylabel('py [mrad]')
# Out:
# Text(0, 0.5, 'py [mrad]')

# %% [markdown]
# > Note: the phase space is unstable on the resonance.

# %% [markdown]
# ### Δημιουργία Κατανομής Σωματιδίων με το `xpart.particles` του Χsuite
#
# - Χρησιμοποιώντας το `xpart.particles` από το **Χsuite**, δημιουργήστε μια κατανομή σωματιδίων με τυχαίες αρχικές συντεταγμένες $x_0$ και $x'_0$, ακολουθώντας μια Γκαουσιανή κατανομή.

# %%
num_particles = 1000 # number of particles
mean_x = 0  # mean position
std_x = 1e-3  # standard deviation of 1 mm for x

mean_xp = 0  # mean angle
std_xp = 1e-3  # standard deviation of 1 mrad for xp

particles = xp.Particles(
    x=np.random.normal(mean_x, std_x, num_particles),
    px=np.random.normal(mean_xp, std_xp, num_particles)
)

# %%
g = sns.jointplot(x=particles.x, y=particles.px, kind="hex", color="b")
g.set_axis_labels("x [mm]", "x' [mrad]")

# %%
import xtrack as xt
import xpart as xp
from cpymad.madx import Madx

mad = Madx()
mad.chdir('psb')
mad.call('psb_flat_bottom.madx')
line= xt.Line.from_madx_sequence(mad.sequence['psb1'],deferred_expressions=True,allow_thick=True)
line.particle_ref=xp.Particles(mass0=xp.PROTON_MASS_EV,gamma0=mad.sequence.psb1.beam.gamma)
line.element_refs['br.c02'].voltage = 0.008*1e6
line.build_tracker()

particles = xp.generate_matched_gaussian_bunch(num_particles=1000,
                                total_intensity_particles=1e10,
                                nemitt_x=1e-6, nemitt_y=1e-6, sigma_z=10,
                                particle_ref=line.particle_ref,
                                line=line
                                )

line.track(particles, num_turns=1, turn_by_turn_monitor='ONE_TURN_EBE') # to save in all elements

for i in range(1000):
    plt.plot(line.record_last_track.s[0], line.record_last_track.y[i]*1e3, '-', lw=0.1, c='blue')
plt.plot(line.record_last_track.s[0], line.record_last_track.y[0]*1e3, '-', lw=3, c='orange', label='Single particle trajectory')
plt.xlabel('s [m]')
plt.ylabel('y [mm]')
# Out:
#   ++++++++++++++++++++++++++++++++++++++++++++
#   +     MAD-X 5.09.03  (64 bit, Linux)       +
#   + Support: mad@cern.ch, http://cern.ch/mad +
#   + Release   date: 2024.04.25               +
#   + Execution date: 2025.04.06 17:28:22      +
#   ++++++++++++++++++++++++++++++++++++++++++++
# /******************************************************************************************
#
#  * BOOSTER
#
#  ******************************************************************************************/
#
#  call, file = 'psb.seq';
#
#
#
#
#
#   /************************************************************************************
#
#   *
#
#   * PS Booster version  (draft) LS2 in MAD X SEQUENCE format
#
#   * Generated the 28-AUG-2020 16:25:27 from Layout
#
#   *
#
#   ************************************************************************************/
#
#
#
#
#
#
#
# /************************************************************************************/
#
# /*                       TYPES DEFINITION                                           */
#
# /************************************************************************************/
#
#
#
# //---------------------- COLLIMATOR     ---------------------------------------------
#
# BR_SPSCRAP     : COLLIMATOR  , L := 0;         ! PSB Special scraper injection & extraction bump, 128mm X 59mm. Thickness 2mm or 3mm (not yet known). //cern.ch/dfs/Departments/TS/Services/Old%20Drawings/Complexe_PS/BOOSTER/49/PS-SI-3-49-1420.TIF
#
# BR_SPSCRAP014  : COLLIMATOR  , L := 0;         ! PSB Special scraper for extraction in P142. Thickness not known. Offset 9mm to the outside. //cern.ch/dfs/Departments/TS/Services/Old%20Drawings/Complexe_PS/BOOSTER/49/PS-SI-3-49-1421.TIF
#
# BR_STSCRAP     : COLLIMATOR  , L := 0;         ! PSB Standard scraper, 122mm X 59mm. Thickness 2mm. //cern.ch/dfs/Departments/TS/Services/Old%20Drawings/Complexe_PS/BOOSTER/49/PS-SI-3-49-1419.TIF
#
# BR_TDIMA       : COLLIMATOR  , L := .07;       ! Beam Dump, Internal, inside Magnet, type A (PSB)
#
# BR_TSAMA002    : COLLIMATOR  , L := 0;         ! Target, Scraper, Absorber, Mask, type A, mobile mask
#
# BR_TSAMA003    : COLLIMATOR  , L := 0;         ! Target, Scraper, Absorber, Mask, type A, fixed mask
#
# //---------------------- HKICKER        ---------------------------------------------
#
# BR_DBSH        : HKICKER     , L := 0;         ! Bumper magnet to shave beam in horizontal plane. Dipoles Type I
#
# BR_DES         : HKICKER     , L := .565;      ! Electrostatic horizontal/vertical stripline deflector
#
# BR_DHZ__001    : HKICKER     , L := 0;         ! DHZ Horizontal Dipole Corrector magnet type 1(nominal current:10A)
#
# BR_DHZ__002    : HKICKER     , L := 0;         ! DHZ Horizontal Dipole Corrector magnet type 2 (nominal current:10A)
#
# BR_DHZ__A      : HKICKER     , L := 0;         ! DHZ Horizontal Dipole Corrector Magnet type A (Multipole, nominal current:270 A)
#
# BR_MKMAG002    : HKICKER     , L := .37;       ! KSW Slow kicker for multiturn injection (magnetic length according to http://accelconf.web.cern.ch/AccelConf/IPAC2015/papers/thpf086.pdf)
#
# BR_MKMAG003    : HKICKER     , L := 2.005789;  ! KFA Fast Extraction kicker
#
# BR_SMH__006    : HKICKER     , L := .95;       ! Extraction Septum
#
# //---------------------- INSTRUMENT     ---------------------------------------------
#
# BR_BCSMA       : INSTRUMENT  , L := 0;         ! Beam Current Stripping foil Monitor, type A
#
# BR_BTVBP036    : INSTRUMENT  , L := 0;         ! Beam TV Booster Type, Pneumatic
#
# BR_BTVBP037    : INSTRUMENT  , L := 0;         ! Beam TV Booster Type, Pneumatic
#
# BR_BTVTS       : INSTRUMENT  , L := 0;         ! Beam observation TV for Stripping foil (Booster)
#
# BR_TKSTR002    : INSTRUMENT  , L := 0;         ! PSB Kickers - Targets:  Stripping Foil Assembly
#
# //---------------------- KICKER         ---------------------------------------------
#
# BR_KQM__002    : KICKER      , L := 1.23;      ! Q kicker tune measurement
#
# //---------------------- MARKER         ---------------------------------------------
#
# BR_VVS         : MARKER      , L := 0;         ! Vacuum Sector Valve (PS Complex)
#
# //---------------------- MONITOR        ---------------------------------------------
#
# BR_BPMTA       : MONITOR     , L := 0;         ! Beam Position Monitor for Tune, type A
#
# BR_BPPBA001    : MONITOR     , L := 0;         ! Beam Position Phase Pick-up, Booster type A
#
# BR_BPPBB001    : MONITOR     , L := 0;         ! Beam Position Phase Pick-up, Booster type B
#
# BR_BWSH        : MONITOR     , L := 0;         ! Wire Scanner Profile Monitor, Horizontal
#
# BR_BWSRA001    : MONITOR     , L := 0;         ! Beam Wire Scanner, Rotational, type A, variant 001
#
# BR_BWSRA002    : MONITOR     , L := 0;         ! Beam Wire Scanner, Rotational, type A, variant 002
#
# BR_BWSV        : MONITOR     , L := 0;         ! Wire Scanner Profile Monitor, Vertical
#
# BR_LBSGWC      : MONITOR     , L := 0;         ! Assembly of SEM Grid with Wire, type C
#
# BR_TDC         : MONITOR     , L := .32;       ! DC Transformer
#
# BR_TFA         : MONITOR     , L := .5293;     ! Beam transformer slow, transfo fast (+transfo slow + transfo intermediaire, but obsolete electronics)
#
# BR_UES         : MONITOR     , L := 0;         ! UES Pick-up Monitor
#
# BR_UQD         : MONITOR     , L := 0;         ! UQD Pick-up Monitor quadrupolar
#
# BR_UTFB        : MONITOR     , L := 0;         ! PU Transverse feedback, electrostatic PU; type F
#
# BR_UWBL        : MONITOR     , L := .3405;     ! Wide band PU, PU wide band (BSM, tomoscope)
#
# //---------------------- MULTIPOLE      ---------------------------------------------
#
# BR_ONO         : MULTIPOLE   , L := 0;         ! Normal Octupole
#
# BR_ONOH0       : MULTIPOLE   , L := 0;         ! Normal Octupole
#
# BR_OSK         : MULTIPOLE   , L := 0;         ! Skew Octupole
#
# BR_QNO__001    : MULTIPOLE   , L := 0;         ! Normal Quadrupole
#
# BR_QSK         : MULTIPOLE   , L := 0;         ! Skew Quadrupole
#
# BR_QSKH0       : MULTIPOLE   , L := 0;         ! QSKH0 Quadrupole Skew
#
# BR_XNOH0       : MULTIPOLE   , L := 0;         ! Normal Sextupole
#
# BR_XNO__001    : MULTIPOLE   , L := 0;         ! Normal Sextupole
#
# BR_XSK         : MULTIPOLE   , L := 0;         ! Skew sextupole
#
# //---------------------- QUADRUPOLE     ---------------------------------------------
#
# BR_MQNEC4WP    : QUADRUPOLE  , L := .50357;    ! Quadrupole magnet, 4 apertures, type QFO - Magnetic length according https://cds.cern.ch/record/1266553/files/CERN-PS-BR-Note-82-11.pdf (value adjusted to fit measured Q-values)
#
# BR_MQNED4WP    : QUADRUPOLE  , L := .50357;    ! Quadrupole magnet, 4 apertures, type QFO extraction - Magnetic length according https://cds.cern.ch/record/1266553/files/CERN-PS-BR-Note-82-11.pdf (value adjusted to fit measured Q-values)
#
# BR_MQNFA4WP    : QUADRUPOLE  , L := .87894;    ! Quadrupole magnet, 4 apertures, type QDE - Magnetic length according https://cds.cern.ch/record/1266553/files/CERN-PS-BR-Note-82-11.pdf (value adjusted to fit measured Q-values)
#
# BR_MQNFJ4WP    : QUADRUPOLE  , L := .87894;    ! Quadrupole magnet, 4 apertures, type QDE with right connections - Magnetic length according https://cds.cern.ch/record/1266553/files/CERN-PS-BR-Note-82-11.pdf (value adjusted to fit measured Q-values)
#
# //---------------------- RBEND          ---------------------------------------------
#
# BR_MDBAAWAP    : HKICKER     , L := .47;       ! Dipole Magnet, bumper, type 5 - Magnetic length according to EDMS: 1512808
#
# BR_MDBABWAP    : HKICKER     , L := .366;      ! Dipole Magnet, bumper, type 6 - Magnetic length according to EDMS: 1512808
#
# BR_MSBSW002    : RBEND       , L := .325;      ! Magnet, Bumper for chicane, Slow, Horizontal (PSB) - BIBSW2
#
# BR_MSBSW003    : RBEND       , L := .325;      ! Magnet, Bumper for chicane, Slow, Horizontal (PSB) - BIBSW3
#
# BR_MSBSW004    : RBEND       , L := .325;      ! Magnet, Bumper for chicane, Slow, Horizontal (PSB) - BIBSW4
#
# BR_MSMIF001    : RBEND       , L := .313;      ! Septum Magnet Injection - type F (PSB) - BIBSW1
#
# //---------------------- RFCAVITY       ---------------------------------------------
#
# BR_ACWFB       : RFCAVITY    , L := .943;      ! Acceleration Cavity Wideband Finemet type B
#
# //---------------------- SBEND          ---------------------------------------------
#
# BR_MBHGC4WP    : SBEND       , L := 1.617696;  ! Bending magnet , Booster, 4 apertures. Alsthom "Normaux" - Dipole magnetic length chosen to be in agreement with the LSA tune control. Information here: https://codimd.web.cern.ch/s/ByB63CBpL#
#
# BR_MBHGD4WP    : SBEND       , L := 1.617696;  ! Bending magnet , Booster ejection, 4 apertures. Alsthom "Speciaux" - Dipole magnetic length chosen to be in agreement with the LSA tune control. Information here: https://codimd.web.cern.ch/s/ByB63CBpL#
#
# BR_MBHGE4WP    : SBEND       , L := 1.617696;  ! Bending magnet , Booster injection, 4 apertures. Alsthom "Speciaux" - Dipole magnetic length chosen to be in agreement with the LSA tune control. Information here: https://codimd.web.cern.ch/s/ByB63CBpL#
#
# //---------------------- VKICKER        ---------------------------------------------
#
# BR_DBSV        : VKICKER     , L := 0;         ! Bumper magnet to shave beam in vertical plane. Dipoles Type I
#
# BR_DVT__001    : VKICKER     , L := 0;         ! DVT Vertical Dipole Corrector Magnet type 1 (nominal current:10A)
#
# BR_DVT__002    : VKICKER     , L := 0;         ! DVT Vertical Dipole Corrector Magnet type 2  (nominal current:10A)
#
# BR_DVT__A      : VKICKER     , L := 0;         ! DVT Vertical Dipole Corrector Magnet Type A  (Multipole, nominal current:270 A)
#
#
#
#
#
#
#
# /************************************************************************************/
#
# /* IDENTICAL EQUIPMENT IN ALL RINGS. AVOIDS WARNINGS OF RE-DEFINITION               */
#
# /************************************************************************************/
#
#
#
# //-----  Scrapers            ---------------------------------------------------------
#
#
#
#  BR.SPSCRAP11        : BR_SPSCRAP   , slot_id = 2458838, assembly_id= 2458836;
#
#  BR.SPSCRAP151       : BR_SPSCRAP   , slot_id = 2459542, assembly_id= 2459540;
#
#  BR.SPSCRAP142       : BR_SPSCRAP014, slot_id = 2459522, assembly_id= 2459493;
#
#  BR.STSCRAP12        : BR_STSCRAP   , slot_id = 2458866, assembly_id= 2458837;
#
#  BR.STSCRAP21        : BR_STSCRAP   , slot_id = 2458881, assembly_id= 2458879;
#
#  BR.STSCRAP22        : BR_STSCRAP   , slot_id = 2458882, assembly_id= 2458880;
#
#  BR.STSCRAP31        : BR_STSCRAP   , slot_id = 2458945, assembly_id= 2458943;
#
#  BR.STSCRAP32        : BR_STSCRAP   , slot_id = 2458946, assembly_id= 2458944;
#
#  BR.STSCRAP41        : BR_STSCRAP   , slot_id = 2459000, assembly_id= 2458998;
#
#  BR.STSCRAP42        : BR_STSCRAP   , slot_id = 2459001, assembly_id= 2458999;
#
#  BR.STSCRAP51        : BR_STSCRAP   , slot_id = 2459043, assembly_id= 2459041;
#
#  BR.STSCRAP52        : BR_STSCRAP   , slot_id = 2459044, assembly_id= 2459042;
#
#  BR.STSCRAP61        : BR_STSCRAP   , slot_id = 2459090, assembly_id= 2459088;
#
#  BR.STSCRAP62        : BR_STSCRAP   , slot_id = 2459091, assembly_id= 2459089;
#
#  BR.STSCRAP71        : BR_STSCRAP   , slot_id = 2459131, assembly_id= 2459129;
#
#  BR.STSCRAP72        : BR_STSCRAP   , slot_id = 2459132, assembly_id= 2459130;
#
#  BR.STSCRAP81        : BR_STSCRAP   , slot_id = 2459198, assembly_id= 2459196;
#
#  BR.STSCRAP82        : BR_STSCRAP   , slot_id = 2459199, assembly_id= 2459197;
#
#  BR.STSCRAP91        : BR_STSCRAP   , slot_id = 2459261, assembly_id= 2459259;
#
#  BR.STSCRAP92        : BR_STSCRAP   , slot_id = 2459262, assembly_id= 2459260;
#
#  BR.STSCRAP101       : BR_STSCRAP   , slot_id = 2459294, assembly_id= 2459292;
#
#  BR.STSCRAP102       : BR_STSCRAP   , slot_id = 2459295, assembly_id= 2459293;
#
#  BR.STSCRAP111       : BR_STSCRAP   , slot_id = 2459345, assembly_id= 2459343;
#
#  BR.STSCRAP112       : BR_STSCRAP   , slot_id = 2459346, assembly_id= 2459344;
#
#  BR.STSCRAP121       : BR_STSCRAP   , slot_id = 2459408, assembly_id= 2459406;
#
#  BR.STSCRAP122       : BR_STSCRAP   , slot_id = 2459409, assembly_id= 2459407;
#
#  BR.STSCRAP131       : BR_STSCRAP   , slot_id = 2459451, assembly_id= 2459449;
#
#  BR.STSCRAP132       : BR_STSCRAP   , slot_id = 2459452, assembly_id= 2459450;
#
#  BR.STSCRAP141       : BR_STSCRAP   , slot_id = 2459494, assembly_id= 2459492;
#
#  BR.STSCRAP152       : BR_STSCRAP   , slot_id = 2459566, assembly_id= 2459541;
#
#  BR.STSCRAP161       : BR_STSCRAP   , slot_id = 2459589, assembly_id= 2459587;
#
#  BR.STSCRAP162       : BR_STSCRAP   , slot_id = 2459590, assembly_id= 2459588;
#
#
#
# //-----  Quadrupole magnets  ---------------------------------------------------------
#
#
#
#  BR.QFO11            : BR_MQNEC4WP, slot_id = 2458839;
#
#  BR.QFO21            : BR_MQNEC4WP, slot_id = 2458883;
#
#  BR.QFO31            : BR_MQNEC4WP, slot_id = 2458947;
#
#  BR.QFO41            : BR_MQNEC4WP, slot_id = 2459002;
#
#  BR.QFO51            : BR_MQNEC4WP, slot_id = 2459045;
#
#  BR.QFO61            : BR_MQNEC4WP, slot_id = 2459092;
#
#  BR.QFO71            : BR_MQNEC4WP, slot_id = 2459137;
#
#  BR.QFO81            : BR_MQNEC4WP, slot_id = 2459204;
#
#  BR.QFO91            : BR_MQNEC4WP, slot_id = 2459263;
#
#  BR.QFO101           : BR_MQNEC4WP, slot_id = 2459296;
#
#  BR.QFO111           : BR_MQNEC4WP, slot_id = 2459351;
#
#  BR.QFO121           : BR_MQNEC4WP, slot_id = 2459410;
#
#  BR.QFO131           : BR_MQNEC4WP, slot_id = 2459453;
#
#  BR.QFO141           : BR_MQNEC4WP, slot_id = 2459495;
#
#  BR.QFO151           : BR_MQNEC4WP, slot_id = 2459543;
#
#  BR.QFO161           : BR_MQNEC4WP, slot_id = 2459591;
#
#  BR.QFO12            : BR_MQNED4WP, slot_id = 2458840;
#
#  BR.QFO22            : BR_MQNED4WP, slot_id = 2458884;
#
#  BR.QFO32            : BR_MQNED4WP, slot_id = 2458948;
#
#  BR.QFO42            : BR_MQNED4WP, slot_id = 2459003;
#
#  BR.QFO52            : BR_MQNED4WP, slot_id = 2459046;
#
#  BR.QFO62            : BR_MQNED4WP, slot_id = 2459093;
#
#  BR.QFO72            : BR_MQNED4WP, slot_id = 2459138;
#
#  BR.QFO82            : BR_MQNED4WP, slot_id = 2459205;
#
#  BR.QFO92            : BR_MQNED4WP, slot_id = 2459264;
#
#  BR.QFO102           : BR_MQNED4WP, slot_id = 2459297;
#
#  BR.QFO112           : BR_MQNED4WP, slot_id = 2459352;
#
#  BR.QFO122           : BR_MQNED4WP, slot_id = 2459411;
#
#  BR.QFO132           : BR_MQNED4WP, slot_id = 2459454;
#
#  BR.QFO142           : BR_MQNED4WP, slot_id = 2459496;
#
#  BR.QFO152           : BR_MQNED4WP, slot_id = 2459544;
#
#  BR.QFO162           : BR_MQNED4WP, slot_id = 2459592;
#
#  BR.QDE3             : BR_MQNFA4WP, slot_id = 2458965;
#
#  BR.QDE4             : BR_MQNFA4WP, slot_id = 2459020;
#
#  BR.QDE7             : BR_MQNFA4WP, slot_id = 2459155;
#
#  BR.QDE8             : BR_MQNFA4WP, slot_id = 2459222;
#
#  BR.QDE11            : BR_MQNFA4WP, slot_id = 2459369;
#
#  BR.QDE12            : BR_MQNFA4WP, slot_id = 2459428;
#
#  BR.QDE15            : BR_MQNFA4WP, slot_id = 2459561;
#
#  BR.QDE16            : BR_MQNFA4WP, slot_id = 2459609;
#
#  BR.QDE1             : BR_MQNFJ4WP, slot_id = 2458861;
#
#  BR.QDE2             : BR_MQNFJ4WP, slot_id = 2458901;
#
#  BR.QDE5             : BR_MQNFJ4WP, slot_id = 2459063;
#
#  BR.QDE6             : BR_MQNFJ4WP, slot_id = 2459110;
#
#  BR.QDE9             : BR_MQNFJ4WP, slot_id = 2459281;
#
#  BR.QDE10            : BR_MQNFJ4WP, slot_id = 2459314;
#
#  BR.QDE13            : BR_MQNFJ4WP, slot_id = 2459471;
#
#  BR.QDE14            : BR_MQNFJ4WP, slot_id = 2459513;
#
#
#
# //-----  Others              ---------------------------------------------------------
#
#
#
#  BR.BHZ11            : BR_MBHGC4WP, slot_id = 2458836;
#
#  BR.BHZ12            : BR_MBHGC4WP, slot_id = 2458837;
#
#  BR.BHZ21            : BR_MBHGC4WP, slot_id = 2458879;
#
#  BR.BHZ22            : BR_MBHGC4WP, slot_id = 2458880;
#
#  BR.BHZ31            : BR_MBHGC4WP, slot_id = 2458943;
#
#  BR.BHZ32            : BR_MBHGC4WP, slot_id = 2458944;
#
#  BR.BHZ41            : BR_MBHGC4WP, slot_id = 2458998;
#
#  BR.BHZ42            : BR_MBHGC4WP, slot_id = 2458999;
#
#  BR.BHZ51            : BR_MBHGC4WP, slot_id = 2459041;
#
#  BR.BHZ52            : BR_MBHGC4WP, slot_id = 2459042;
#
#  BR.BHZ61            : BR_MBHGC4WP, slot_id = 2459088;
#
#  BR.BHZ62            : BR_MBHGC4WP, slot_id = 2459089;
#
#  BR.BHZ71            : BR_MBHGC4WP, slot_id = 2459129;
#
#  BR.BHZ72            : BR_MBHGC4WP, slot_id = 2459130;
#
#  BR.BHZ81            : BR_MBHGC4WP, slot_id = 2459196;
#
#  BR.BHZ82            : BR_MBHGC4WP, slot_id = 2459197;
#
#  BR.BHZ91            : BR_MBHGC4WP, slot_id = 2459259;
#
#  BR.BHZ92            : BR_MBHGC4WP, slot_id = 2459260;
#
#  BR.BHZ101           : BR_MBHGC4WP, slot_id = 2459292;
#
#  BR.BHZ102           : BR_MBHGC4WP, slot_id = 2459293;
#
#  BR.BHZ111           : BR_MBHGC4WP, slot_id = 2459343;
#
#  BR.BHZ112           : BR_MBHGC4WP, slot_id = 2459344;
#
#  BR.BHZ121           : BR_MBHGC4WP, slot_id = 2459406;
#
#  BR.BHZ122           : BR_MBHGC4WP, slot_id = 2459407;
#
#  BR.BHZ131           : BR_MBHGC4WP, slot_id = 2459449;
#
#  BR.BHZ132           : BR_MBHGC4WP, slot_id = 2459450;
#
#  BR.BHZ141           : BR_MBHGC4WP, slot_id = 2459492;
#
#  BR.BHZ142           : BR_MBHGC4WP, slot_id = 2459493;
#
#  BR.BHZ152           : BR_MBHGC4WP, slot_id = 2459540;
#
#  BR.BHZ161           : BR_MBHGC4WP, slot_id = 2459541;
#
#  BR.BHZ151           : BR_MBHGD4WP, slot_id = 2459587;
#
#  BR.BHZ162           : BR_MBHGE4WP, slot_id = 2459588;
#
#
#
#
#
# /************************************************************************************/
#
# /*                       PSB SEQUENCES                                              */
#
# /************************************************************************************/
#
#
#
#
#
#   /*********************************************************
#
#   * Basic period (for reference)
#
#   **********************************************************
#
#   PERIOD: sequence, refer = centre , l  =   9.81750;
#
#   L1                               , at =   1.3269999985;
#
#   B1                               , at =   3.46284869;
#
#   L2                               , at =   4.4548473865;
#
#   QF                               , at =   4.88979739;
#
#   L3                               , at =   5.46847239;
#
#   QD                               , at =   6.23479739;
#
#   L4                               , at =   7.00162239;
#
#   QF                               , at =   7.58079739;
#
#   L5                               , at =   8.0162000035;
#
#   B1                               , at =   9.00865131;
#
#   endsequence;
#
#   *********************************************************/
#
#
#
#   //------------------------------------------------------------------------------------
#
# //                       RING 1
#
# //------------------------------------------------------------------------------------
#
#
#
# P01ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 01
#
#   BI1.BSW1L1.1        : BR_MSMIF001     , at = .336         , slot_id = 43192227;
#
#   BI1.BSW1L1.2        : BR_MSBSW002     , at = 1.032        , slot_id = 43198754;
#
#   BI1.BTV1L1          : BR_BTVTS        , at = 1.327628     , slot_id = 43201381;
#
#   BI1.BCSF1L1         : BR_BCSMA        , at = 1.334        , slot_id = 43201377;
#
#   BI1.TSTR1L1         : BR_TKSTR002     , at = 1.334        , slot_id = 43201373;
#
#   BI1.BSW1L1.3        : BR_MSBSW003     , at = 1.56         , slot_id = 43201385;
#
#   BI1.BSW1L1.4        : BR_MSBSW004     , at = 2.256        , slot_id = 43201395;
#
#   BI1.TDI1L1          : BR_TDIMA        , at = 2.491        , slot_id = 43201399;
#
#   BR.BHZ11                              , at = 3.462849;
#
#   BR.SPSCRAP11                          , at = 4.2717;
#
#   BR1.VVS1L2          : BR_VVS          , at = 4.514819     , slot_id = 54716799;
#
#   BR.QFO11                              , at = 4.889797;
#
#   BR1.BPM1L3          : BR_UES          , at = 5.467797     , slot_id = 2458847, assembly_id= 2452397;
#
#   BR1.ONOH0.1L3       : BR_ONOH0        , at = 5.467797     , slot_id = 2458845, assembly_id= 2452398;
#
#   BR1.QSKH0.1L3       : BR_QSKH0        , at = 5.467797     , slot_id = 2458846, assembly_id= 2452398;
#
#   BR1.XNOH0.1L3       : BR_XNOH0        , at = 5.467797     , slot_id = 2458848, assembly_id= 2452398;
#
#   BR.QDE1                               , at = 6.234797;
#
#   BI1.KSW1L4          : BR_MKMAG002     , at = 7.001797     , slot_id = 2458862, assembly_id= 5736975;
#
#   BR.QFO12                              , at = 7.580797;
#
#   BR1.BPP1L5          : BR_BPPBA001     , at = 7.997852     , slot_id = 2458841, assembly_id= 2452396;
#
#   BR.STSCRAP12                          , at = 8.199799;
#
#   BR.BHZ12                              , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P02ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 02
#
#   BR1.BWS.2L1.V_ROT   : BR_BWSV         , at = .918         , slot_id = 2458867, assembly_id= 2452403;
#
#   BR1.BWS.2L1.H_ROT   : BR_BWSH         , at = 1.016        , slot_id = 2458871, assembly_id= 2452403;
#
#   BI1.KSW2L1          : BR_MKMAG002     , at = 1.737        , slot_id = 2458875, assembly_id= 5736984;
#
#   BR.BHZ21                              , at = 3.462849;
#
#   BR.STSCRAP21                          , at = 4.2716995;
#
#   BR.QFO21                              , at = 4.889797;
#
#   BR1.BPM2L3          : BR_UES          , at = 5.467802     , slot_id = 2458887, assembly_id= 2452406;
#
#   BR1.ONOH0.2L3       : BR_ONOH0        , at = 5.467802     , slot_id = 2458885, assembly_id= 2452407;
#
#   BR1.QSK2L3          : BR_QSK          , at = 5.467802     , slot_id = 2458886, assembly_id= 2452407;
#
#   BR1.XNOH0.2L3       : BR_XNOH0        , at = 5.467802     , slot_id = 2458888, assembly_id= 2452407;
#
#   BR.QDE2                               , at = 6.234797;
#
#   BR1.DHZ2L4          : BR_DHZ__A       , at = 7.001802     , slot_id = 2458902, assembly_id= 2452411;
#
#   BR1.DVT2L4          : BR_DVT__A       , at = 7.001802     , slot_id = 2458903, assembly_id= 2452411;
#
#   BR1.OSK2L4          : BR_OSK          , at = 7.001802     , slot_id = 2458904, assembly_id= 2452411;
#
#   BR1.XSK2L4          : BR_XSK          , at = 7.001802     , slot_id = 2458905, assembly_id= 2452411;
#
#   BR.QFO22                              , at = 7.580797;
#
#   BR.STSCRAP22                          , at = 8.199799;
#
#   BR.BHZ22                              , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P03ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 03
#
#   BR1.DES3L1          : BR_DES          , at = .8065        , slot_id = 2458918, assembly_id= 2452415;
#
#   BR1.ONO3L1          : BR_ONO          , at = 1.463        , slot_id = 2458926, assembly_id= 2452417;
#
#   BR1.QNO3L1          : BR_QNO__001     , at = 1.463        , slot_id = 2458927, assembly_id= 2452417;
#
#   BR1.UQD3L1          : BR_UQD          , at = 1.463        , slot_id = 2458928, assembly_id= 2452417;
#
#   BR1.XNO3L1          : BR_XNO__001     , at = 1.463        , slot_id = 2458929, assembly_id= 2452417;
#
#   BR1.BPMT3L1         : BR_BPMTA        , at = 2.043        , slot_id = 2458939, assembly_id= 2452421;
#
#   BR.BHZ31                              , at = 3.462849;
#
#   BR.STSCRAP31                          , at = 4.2717;
#
#   BR.QFO31                              , at = 4.889797;
#
#   BR1.BPM3L3          : BR_UES          , at = 5.467807     , slot_id = 2458951, assembly_id= 2452422;
#
#   BR1.ONOH0.3L3       : BR_ONOH0        , at = 5.467807     , slot_id = 2458949, assembly_id= 2452423;
#
#   BR1.QSKH0.3L3       : BR_QSKH0        , at = 5.467807     , slot_id = 2458950, assembly_id= 2452423;
#
#   BR1.XNOH0.3L3       : BR_XNOH0        , at = 5.467807     , slot_id = 2458952, assembly_id= 2452423;
#
#   BR.QDE3                               , at = 6.234797;
#
#   BR1.DHZ3L4          : BR_DHZ__001     , at = 7.001807     , slot_id = 2458966, assembly_id= 2452427;
#
#   BR1.DVT3L4          : BR_DVT__001     , at = 7.001807     , slot_id = 2458967, assembly_id= 2452427;
#
#   BR.QFO32                              , at = 7.580797;
#
#   BR.STSCRAP32                          , at = 8.199799;
#
#   BR.BHZ32                              , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P04ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 04
#
#   BR1.ONO4L1          : BR_ONO          , at = .37          , slot_id = 2458974, assembly_id= 2452431;
#
#   BR1.OSK4L1          : BR_OSK          , at = .37          , slot_id = 2458975, assembly_id= 2452431;
#
#   BR1.XNO4L1          : BR_XNO__001     , at = .37          , slot_id = 2458976, assembly_id= 2452431;
#
#   BR1.XSK4L1          : BR_XSK          , at = .37          , slot_id = 2458977, assembly_id= 2452431;
#
#   BE1.DHZ4L1          : BR_DHZ__001     , at = .904         , slot_id = 2458990, assembly_id= 2452435;
#
#   BE1.DVT4L1          : BR_DVT__001     , at = .904         , slot_id = 2458991, assembly_id= 2452435;
#
#   BR1.BWSH4L1         : BR_BWSRA001     , at = 2.134        , slot_id = 43177294;
#
#   BR.BHZ41                              , at = 3.462849;
#
#   BR.STSCRAP41                          , at = 4.2716995;
#
#   BR.QFO41                              , at = 4.889797;
#
#   BR1.BPM4L3          : BR_UES          , at = 5.467812     , slot_id = 2459006, assembly_id= 2452439;
#
#   BR1.ONOH0.4L3       : BR_ONOH0        , at = 5.467812     , slot_id = 2459004, assembly_id= 2452440;
#
#   BR1.QNO4L3          : BR_QNO__001     , at = 5.467812     , slot_id = 2459005, assembly_id= 2452440;
#
#   BR1.XNOH0.4L3       : BR_XNOH0        , at = 5.467812     , slot_id = 2459007, assembly_id= 2452440;
#
#   BR.QDE4                               , at = 6.234797;
#
#   BR1.DHZ4L4          : BR_DHZ__001     , at = 7.001812     , slot_id = 2459021, assembly_id= 2452444;
#
#   BR1.DVT4L4          : BR_DVT__001     , at = 7.001812     , slot_id = 52943127, assembly_id= 2452444;
#
#   BR.QFO42                              , at = 7.580797;
#
#   BR1.BPTF4L5         : BR_UTFB         , at = 7.99794      , slot_id = 2459029, assembly_id= 2452448;
#
#   BR.STSCRAP42                          , at = 8.199799;
#
#   BR.BHZ42                              , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P05ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 05
#
#   BR1.ACWF5L1.1       : BR_ACWFB        , at = .722761      , slot_id = 43086683, assembly_id= 43086680;
#
#   BR1.ACWF5L1.2       : BR_ACWFB        , at = 1.777261     , slot_id = 43086689, assembly_id= 43086680;
#
#   BR.BHZ51                              , at = 3.462849;
#
#   BR.STSCRAP51                          , at = 4.2716995;
#
#   BR.QFO51                              , at = 4.889797;
#
#   BR1.BPM5L3          : BR_UES          , at = 5.467806     , slot_id = 2459049, assembly_id= 2452451;
#
#   BR1.ONOH0.5L3       : BR_ONOH0        , at = 5.467806     , slot_id = 2459047, assembly_id= 2452452;
#
#   BR1.QSKH0.5L3       : BR_QSKH0        , at = 5.467806     , slot_id = 2459048, assembly_id= 2452452;
#
#   BR1.XNOH0.5L3       : BR_XNOH0        , at = 5.467806     , slot_id = 2459050, assembly_id= 2452452;
#
#   BR.QDE5                               , at = 6.234797;
#
#   BR1.DHZ5L4          : BR_DHZ__001     , at = 6.840806     , slot_id = 2459064, assembly_id= 2452456;
#
#   BR1.DVT5L4          : BR_DVT__001     , at = 6.840806     , slot_id = 2459065, assembly_id= 2452456;
#
#   BR.QFO52                              , at = 7.580797;
#
#   BR.STSCRAP52                          , at = 8.199799;
#
#   BR.BHZ52                              , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P06ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 06
#
#   BR1.ONO6L1          : BR_ONO          , at = .37          , slot_id = 2459072, assembly_id= 2452460;
#
#   BR1.OSK6L1          : BR_OSK          , at = .37          , slot_id = 2459073, assembly_id= 2452460;
#
#   BR1.XNO6L1          : BR_XNO__001     , at = .37          , slot_id = 2459074, assembly_id= 2452460;
#
#   BR1.XSK6L1          : BR_XSK          , at = .37          , slot_id = 2459075, assembly_id= 2452460;
#
#   BR.BHZ61                              , at = 3.462849;
#
#   BR.STSCRAP61                          , at = 4.2717;
#
#   BR.QFO61                              , at = 4.889797;
#
#   BR1.BPM6L3          : BR_UES          , at = 5.467811     , slot_id = 2459096, assembly_id= 2452464;
#
#   BR1.ONOH0.6L3       : BR_ONOH0        , at = 5.467811     , slot_id = 2459094, assembly_id= 2452465;
#
#   BR1.QSK6L3          : BR_QSK          , at = 5.467811     , slot_id = 2459095, assembly_id= 2452465;
#
#   BR1.XNOH0.6L3       : BR_XNOH0        , at = 5.467811     , slot_id = 2459097, assembly_id= 2452465;
#
#   BR.QDE6                               , at = 6.234797;
#
#   BR1.DHZ6L4          : BR_DHZ__A       , at = 7.001811     , slot_id = 2459111, assembly_id= 2452469;
#
#   BR1.DVT6L4          : BR_DVT__A       , at = 7.001811     , slot_id = 2459112, assembly_id= 2452469;
#
#   BR1.OSK6L4          : BR_OSK          , at = 7.001811     , slot_id = 2459113, assembly_id= 2452469;
#
#   BR1.XSK6L4          : BR_XSK          , at = 7.001811     , slot_id = 2459114, assembly_id= 2452469;
#
#   BR.QFO62                              , at = 7.580797;
#
#   BR.STSCRAP62                          , at = 8.1998;
#
#   BR.BHZ62                              , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P07ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 07
#
#   BR1.ACWF7L1.1       : BR_ACWFB        , at = .722761      , slot_id = 43086773, assembly_id= 43086681;
#
#   BR1.ACWF7L1.2       : BR_ACWFB        , at = 1.777261     , slot_id = 43086777, assembly_id= 43086681;
#
#   BR.BHZ71                              , at = 3.462849;
#
#   BR.STSCRAP71                          , at = 4.2717;
#
#   BR.QFO71                              , at = 4.889797;
#
#   BR1.BPM7L3          : BR_UES          , at = 5.467816     , slot_id = 2459141, assembly_id= 2452475;
#
#   BR1.ONOH0.7L3       : BR_ONOH0        , at = 5.467816     , slot_id = 2459139, assembly_id= 2452476;
#
#   BR1.QSKH0.7L3       : BR_QSKH0        , at = 5.467816     , slot_id = 2459140, assembly_id= 2452476;
#
#   BR1.XNOH0.7L3       : BR_XNOH0        , at = 5.467816     , slot_id = 2459142, assembly_id= 2452476;
#
#   BR.QDE7                               , at = 6.234797;
#
#   BR1.DSHAH7L4        : BR_DBSH         , at = 7.001816     , slot_id = 2459156, assembly_id= 2452480;
#
#   BR1.DSHAV7L4        : BR_DBSV         , at = 7.001816     , slot_id = 2459157, assembly_id= 2452480;
#
#   BR.QFO72                              , at = 7.580797;
#
#   BR.STSCRAP72                          , at = 8.1998;
#
#   BR.BHZ72                              , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P08ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 08
#
#   BR1.ONO8L1          : BR_ONO          , at = .36375       , slot_id = 2459164, assembly_id= 2452484;
#
#   BR1.QNO8L1          : BR_QNO__001     , at = .36375       , slot_id = 2459165, assembly_id= 2452484;
#
#   BR1.XNO8L1          : BR_XNO__001     , at = .36375       , slot_id = 2459166, assembly_id= 2452484;
#
#   BR1.DHZ8L1          : BR_DHZ__001     , at = .86675       , slot_id = 2459176, assembly_id= 2452488;
#
#   BR1.DVT8L1          : BR_DVT__001     , at = .86675       , slot_id = 2459177, assembly_id= 2452488;
#
#   BR1.BCTF8L1         : BR_TFA          , at = 1.4824       , slot_id = 2459184, assembly_id= 2452492;
#
#   BR1.BCW8L1          : BR_UWBL         , at = 2.013023     , slot_id = 2459188, assembly_id= 2452493;
#
#   BR1.VVS8L1          : BR_VVS          , at = 2.318723     , slot_id = 3783284;
#
#   BR1.BPP8L1          : BR_BPPBA001     , at = 2.465723     , slot_id = 2459192, assembly_id= 2452494;
#
#   BR.BHZ81                              , at = 3.462849;
#
#   BR.STSCRAP81                          , at = 4.2716995;
#
#   BR.QFO81                              , at = 4.889797;
#
#   BR1.BPM8L3          : BR_UES          , at = 5.467821     , slot_id = 2459208, assembly_id= 2452496;
#
#   BR1.ONOH0.8L3       : BR_ONOH0        , at = 5.467821     , slot_id = 2459206, assembly_id= 2452497;
#
#   BR1.QNO8L3          : BR_QNO__001     , at = 5.467821     , slot_id = 2459207, assembly_id= 2452497;
#
#   BR1.XNOH0.8L3       : BR_XNOH0        , at = 5.467821     , slot_id = 2459209, assembly_id= 2452497;
#
#   BR.QDE8                               , at = 6.234797;
#
#   BR1.TSAA8L4         : BR_TSAMA002     , at = 6.971297     , slot_id = 43977854, assembly_id= 43073735;
#
#   BR1.TSAB8L4         : BR_TSAMA003     , at = 7.143297     , slot_id = 53666506, assembly_id= 43073735;
#
#   BR.QFO82                              , at = 7.580797;
#
#   BR.STSCRAP82                          , at = 8.1998;
#
#   BR.BHZ82                              , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P09ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 09
#
#   BR1.DHZ9L1          : BR_DHZ__001     , at = .384         , slot_id = 2459231, assembly_id= 2452505;
#
#   BR1.DVT9L1          : BR_DVT__001     , at = .384         , slot_id = 2459232, assembly_id= 2452505;
#
#   BR1.BCTDC9L1        : BR_TDC          , at = 1.0289       , slot_id = 2459239;
#
#   BR1.ONO9L1          : BR_ONO          , at = 2.094        , slot_id = 2459243, assembly_id= 2452511;
#
#   BR1.OSK9L1          : BR_OSK          , at = 2.094        , slot_id = 2459244, assembly_id= 2452511;
#
#   BR1.XNO9L1          : BR_XNO__001     , at = 2.094        , slot_id = 2459245, assembly_id= 2452511;
#
#   BR1.XSK9L1          : BR_XSK          , at = 2.094        , slot_id = 2459246, assembly_id= 2452511;
#
#   BR.BHZ91                              , at = 3.462849;
#
#   BR.STSCRAP91                          , at = 4.2716995;
#
#   BR.QFO91                              , at = 4.889797;
#
#   BR1.BPM9L3          : BR_UES          , at = 5.467826     , slot_id = 2459267, assembly_id= 2452515;
#
#   BR1.ONOH0.9L3       : BR_ONOH0        , at = 5.467826     , slot_id = 2459265, assembly_id= 2452516;
#
#   BR1.QSKH0.9L3       : BR_QSKH0        , at = 5.467826     , slot_id = 2459266, assembly_id= 2452516;
#
#   BR1.XNOH0.9L3       : BR_XNOH0        , at = 5.467826     , slot_id = 2459268, assembly_id= 2452516;
#
#   BR.QDE9                               , at = 6.234797;
#
#   BR1.DSHAH9L4        : BR_DBSH         , at = 7.001826     , slot_id = 2459282, assembly_id= 2452520;
#
#   BR1.DSHAV9L4        : BR_DBSV         , at = 7.001826     , slot_id = 2459283, assembly_id= 2452520;
#
#   BR.QFO92                              , at = 7.580797;
#
#   BR.STSCRAP92                          , at = 8.199799;
#
#   BR.BHZ92                              , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P10ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 10
#
#   BR.BHZ101                             , at = 3.462849;
#
#   BR.STSCRAP101                         , at = 4.2716995;
#
#   BR.QFO101                             , at = 4.889797;
#
#   BR1.BPM10L3         : BR_UES          , at = 5.46782      , slot_id = 2459300, assembly_id= 2452525;
#
#   BR1.ONOH0.10L3      : BR_ONOH0        , at = 5.46782      , slot_id = 2459298, assembly_id= 2452526;
#
#   BR1.QSK10L3         : BR_QSK          , at = 5.46782      , slot_id = 2459299, assembly_id= 2452526;
#
#   BR1.XNOH0.10L3      : BR_XNOH0        , at = 5.46782      , slot_id = 2459301, assembly_id= 2452526;
#
#   BR.QDE10                              , at = 6.234797;
#
#   BR1.DHZ10L4         : BR_DHZ__001     , at = 7.00182      , slot_id = 52943216, assembly_id= 2452530;
#
#   BR1.DVT10L4         : BR_DVT__001     , at = 7.00182      , slot_id = 2459316, assembly_id= 2452530;
#
#   BR.QFO102                             , at = 7.580797;
#
#   BR.STSCRAP102                         , at = 8.1998;
#
#   BR.BHZ102                             , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P11ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 11
#
#   BE1.DHZ11L1         : BR_DHZ__001     , at = .296         , slot_id = 2459323, assembly_id= 2452534;
#
#   BE1.DVT11L1         : BR_DVT__001     , at = .296         , slot_id = 2459324, assembly_id= 2452534;
#
#   BR1.ONO11L1         : BR_ONO          , at = 1.463        , slot_id = 2459331, assembly_id= 2452538;
#
#   BR1.QNO11L1         : BR_QNO__001     , at = 1.463        , slot_id = 2459332, assembly_id= 2452538;
#
#   BR1.XNO11L1         : BR_XNO__001     , at = 1.463        , slot_id = 2459333, assembly_id= 2452538;
#
#   BR1.BWSV11L1        : BR_BWSRA002     , at = 2.163677     , slot_id = 43177298;
#
#   BR.BHZ111                             , at = 3.462849;
#
#   BR.STSCRAP111                         , at = 4.2716995;
#
#   BR1.BPP11L2         : BR_BPPBA001     , at = 4.3037       , slot_id = 2459347, assembly_id= 2452542;
#
#   BR.QFO111                             , at = 4.889797;
#
#   BR1.BPM11L3         : BR_UES          , at = 5.467825     , slot_id = 2459355, assembly_id= 2452543;
#
#   BR1.ONOH0.11L3      : BR_ONOH0        , at = 5.467825     , slot_id = 2459353, assembly_id= 2452544;
#
#   BR1.QSKH0.11L3      : BR_QSKH0        , at = 5.467825     , slot_id = 2459354, assembly_id= 2452544;
#
#   BR1.XNOH0.11L3      : BR_XNOH0        , at = 5.467825     , slot_id = 2459356, assembly_id= 2452544;
#
#   BR.QDE11                              , at = 6.234797;
#
#   BR1.DHZ11L4         : BR_DHZ__A       , at = 7.001825     , slot_id = 2459370, assembly_id= 2452548;
#
#   BR1.DVT11L4         : BR_DVT__A       , at = 7.001825     , slot_id = 2459371, assembly_id= 2452548;
#
#   BR1.OSK11L4         : BR_OSK          , at = 7.001825     , slot_id = 2459372, assembly_id= 2452548;
#
#   BR1.XSK11L4         : BR_XSK          , at = 7.001825     , slot_id = 2459373, assembly_id= 2452548;
#
#   BR.QFO112                             , at = 7.580797;
#
#   BR.STSCRAP112                         , at = 8.1998;
#
#   BR.BHZ112                             , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P12ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 12
#
#   BR1.KQM12L1         : BR_KQM__002     , at = .914         , slot_id = 2459386, assembly_id= 2452552;
#
#   BR1.ONO12L1         : BR_ONO          , at = 2.094        , slot_id = 2459390, assembly_id= 2452553;
#
#   BR1.OSK12L1         : BR_OSK          , at = 2.094        , slot_id = 2459391, assembly_id= 2452553;
#
#   BR1.XNO12L1         : BR_XNO__001     , at = 2.094        , slot_id = 2459392, assembly_id= 2452553;
#
#   BR1.XSK12L1         : BR_XSK          , at = 2.094        , slot_id = 2459393, assembly_id= 2452553;
#
#   BR.BHZ121                             , at = 3.462849;
#
#   BR.STSCRAP121                         , at = 4.2716995;
#
#   BR.QFO121                             , at = 4.889797;
#
#   BR1.BPM12L3         : BR_UES          , at = 5.46783      , slot_id = 2459414, assembly_id= 2452557;
#
#   BR1.ONOH0.12L3      : BR_ONOH0        , at = 5.46783      , slot_id = 2459412, assembly_id= 2452558;
#
#   BR1.QNO12L3         : BR_QNO__001     , at = 5.46783      , slot_id = 2459413, assembly_id= 2452558;
#
#   BR1.XNOH0.12L3      : BR_XNOH0        , at = 5.46783      , slot_id = 2459415, assembly_id= 2452558;
#
#   BR.QDE12                              , at = 6.234797;
#
#   BR1.DHZ12L4         : BR_DHZ__A       , at = 7.00183      , slot_id = 2459429, assembly_id= 2452562;
#
#   BR1.DVT12L4         : BR_DVT__A       , at = 7.00183      , slot_id = 2459430, assembly_id= 2452562;
#
#   BR1.OSK12L4         : BR_OSK          , at = 7.00183      , slot_id = 2459431, assembly_id= 2452562;
#
#   BR1.XSK12L4         : BR_XSK          , at = 7.00183      , slot_id = 2459432, assembly_id= 2452562;
#
#   BR.QFO122                             , at = 7.580797;
#
#   BR.STSCRAP122                         , at = 8.199799;
#
#   BR.BHZ122                             , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P13ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 13
#
#   BR1.ACWF13L1.1      : BR_ACWFB        , at = .722761      , slot_id = 43086789, assembly_id= 43086682;
#
#   BR1.ACWF13L1.2      : BR_ACWFB        , at = 1.777261     , slot_id = 43086793, assembly_id= 43086682;
#
#   BR.BHZ131                             , at = 3.462849;
#
#   BR.STSCRAP131                         , at = 4.2716995;
#
#   BR.QFO131                             , at = 4.889797;
#
#   BR1.BPM13L3         : BR_UES          , at = 5.467835     , slot_id = 2459457, assembly_id= 2452567;
#
#   BR1.ONOH0.13L3      : BR_ONOH0        , at = 5.467835     , slot_id = 2459455, assembly_id= 2452568;
#
#   BR1.QSKH0.13L3      : BR_QSKH0        , at = 5.467835     , slot_id = 2459456, assembly_id= 2452568;
#
#   BR1.XNOH0.13L3      : BR_XNOH0        , at = 5.467835     , slot_id = 2459458, assembly_id= 2452568;
#
#   BR.QDE13                              , at = 6.234797;
#
#   BR1.DHZ13L4         : BR_DHZ__001     , at = 7.001835     , slot_id = 2459472, assembly_id= 2452572;
#
#   BR1.DVT13L4         : BR_DVT__001     , at = 7.001835     , slot_id = 2459473, assembly_id= 2452572;
#
#   BR.QFO132                             , at = 7.580797;
#
#   BR.STSCRAP132                         , at = 8.199799;
#
#   BR.BHZ132                             , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P14ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 14
#
#   BR1.DHZ14L1         : BR_DHZ__001     , at = .30659       , slot_id = 2459480, assembly_id= 2452576;
#
#   BR1.DVT14L1         : BR_DVT__001     , at = .30659       , slot_id = 2459481, assembly_id= 2452576;
#
#   BE1.KFA14L1         : BR_MKMAG003     , at = 1.52659      , slot_id = 2459488, assembly_id= 5736994;
#
#   BR.BHZ141                             , at = 3.462849;
#
#   BR.STSCRAP141                         , at = 4.2716995;
#
#   BR1.VVS14L2         : BR_VVS          , at = 4.3725       , slot_id = 3783356;
#
#   BR.QFO141                             , at = 4.889797;
#
#   BR1.BPM14L3         : BR_UES          , at = 5.467839     , slot_id = 2459499, assembly_id= 2452581;
#
#   BR1.ONOH0.14L3      : BR_ONOH0        , at = 5.467839     , slot_id = 2459497, assembly_id= 2452582;
#
#   BR1.QSK14L3         : BR_QSK          , at = 5.467839     , slot_id = 2459498, assembly_id= 2452582;
#
#   BR1.XNOH0.14L3      : BR_XNOH0        , at = 5.467839     , slot_id = 2459500, assembly_id= 2452582;
#
#   BR.QDE14                              , at = 6.234797;
#
#   BR1.BPP14L4         : BR_BPPBB001     , at = 6.79374      , slot_id = 2459514, assembly_id= 2452586;
#
#   BE1.BSW14L4         : BR_MDBAAWAP     , at = 7.06474      , slot_id = 2459518;
#
#   BR.QFO142                             , at = 7.580797;
#
#   BR.SPSCRAP142                         , at = 8.199799;
#
#   BR.BHZ142                             , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P15ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 15
#
#   BE1.BTV10           : BR_BTVBP036     , at = .225173      , slot_id = 52941789, assembly_id= 52941725;
#
#   BR1.BTV15L1         : BR_BTVBP037     , at = .270573      , slot_id = 52941747, assembly_id= 52941725;
#
#   BE1.SMH15L1         : BR_SMH__006     , at = 1.026102     , slot_id = 2459524, assembly_id= 2452588;
#
#   BR1.DHZ15L1         : BR_DHZ__002     , at = 1.842652     , slot_id = 2459528, assembly_id= 2452589;
#
#   BR1.DVT15L1         : BR_DVT__002     , at = 1.842652     , slot_id = 2459529, assembly_id= 2452589;
#
#   BE1.BSW15L1         : BR_MDBABWAP     , at = 2.36866      , slot_id = 2459536;
#
#   BR.BHZ151                             , at = 3.462849;
#
#   BR.SPSCRAP151                         , at = 4.2716995;
#
#   BR.QFO151                             , at = 4.889797;
#
#   BR1.BPM15L3         : BR_UES          , at = 5.467834     , slot_id = 2459547, assembly_id= 2452594;
#
#   BR1.ONOH0.15L3      : BR_ONOH0        , at = 5.467834     , slot_id = 2459545, assembly_id= 2452595;
#
#   BR1.QSKH0.15L3      : BR_QSKH0        , at = 5.467834     , slot_id = 2459546, assembly_id= 2452595;
#
#   BR1.XNOH0.15L3      : BR_XNOH0        , at = 5.467834     , slot_id = 2459548, assembly_id= 2452595;
#
#   BR.QDE15                              , at = 6.234797;
#
#   BE1.BSW15L4         : BR_MDBAAWAP     , at = 7.011834     , slot_id = 2459562;
#
#   BR.QFO152                             , at = 7.580797;
#
#   BR.STSCRAP152                         , at = 8.199799;
#
#   BR.BHZ152                             , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P16ring1: SEQUENCE, refer = centre, L  = 9.8175; !Ring 1, Period 16
#
#   BR1.ONO16L1         : BR_ONO          , at = .363         , slot_id = 2459567, assembly_id= 2452600;
#
#   BR1.QNO16L1         : BR_QNO__001     , at = .363         , slot_id = 2459568, assembly_id= 2452600;
#
#   BR1.XNO16L1         : BR_XNO__001     , at = .363         , slot_id = 2459569, assembly_id= 2452600;
#
#   BI1.KSW16L1         : BR_MKMAG002     , at = .9605        , slot_id = 40101120, assembly_id= 40101119;
#
#   BR1.DHZ16L1         : BR_DHZ__001     , at = 1.99601      , slot_id = 2459579, assembly_id= 2452604;
#
#   BR1.DVT16L1         : BR_DVT__001     , at = 1.99601      , slot_id = 2459580, assembly_id= 2452604;
#
#   BR.BHZ161                             , at = 3.462849;
#
#   BR.STSCRAP161                         , at = 4.2717;
#
#   BR.QFO161                             , at = 4.889797;
#
#   BR1.BPM16L3         : BR_UES          , at = 5.467839     , slot_id = 2459595, assembly_id= 2452608;
#
#   BR1.ONOH0.16L3      : BR_ONOH0        , at = 5.467839     , slot_id = 2459593, assembly_id= 2452609;
#
#   BR1.QNO16L3         : BR_QNO__001     , at = 5.467839     , slot_id = 2459594, assembly_id= 2452609;
#
#   BR1.XNOH0.16L3      : BR_XNOH0        , at = 5.467839     , slot_id = 2459596, assembly_id= 2452609;
#
#   BR.QDE16                              , at = 6.234797;
#
#   BI1.KSW16L4         : BR_MKMAG002     , at = 7.001839     , slot_id = 2459610, assembly_id= 5736989;
#
#   BR.QFO162                             , at = 7.580797;
#
#   BR1.VVS16L5         : BR_VVS          , at = 7.955897     , slot_id = 54717179;
#
#   BR.STSCRAP162                         , at = 8.199799;
#
#   BR.BHZ162                             , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# //------------------------------------------------------------------------------------
#
# //                       RING 2
#
# //------------------------------------------------------------------------------------
#
#
#
# P01ring2: SEQUENCE, refer = centre, L  = 9.8175; !Ring 2, Period 01
#
#   BI2.BSW1L1.1        : BR_MSMIF001     , at = .336         , slot_id = 43201351;
#
#   BI2.BSW1L1.2        : BR_MSBSW002     , at = 1.032        , slot_id = 43201370;
#
#   BI2.BTV1L1          : BR_BTVTS        , at = 1.327628     , slot_id = 43201382;
#
#   BI2.BCSF1L1         : BR_BCSMA        , at = 1.334        , slot_id = 43201378;
#
#   BI2.TSTR1L1         : BR_TKSTR002     , at = 1.334        , slot_id = 43201374;
#
#   BI2.BSW1L1.3        : BR_MSBSW003     , at = 1.56         , slot_id = 43201386;
#
#   BI2.BSW1L1.4        : BR_MSBSW004     , at = 2.256        , slot_id = 43201396;
#
#   BI2.TDI1L1          : BR_TDIMA        , at = 2.491        , slot_id = 43201400;
#
#   BR.BHZ11                              , at = 3.462849;
#
#   BR.SPSCRAP11                          , at = 4.2717;
#
#   BR2.VVS1L2          : BR_VVS          , at = 4.514819     , slot_id = 54716836;
#
#   BR.QFO11                              , at = 4.889797;
#
#   BR2.BPM1L3          : BR_UES          , at = 5.467797     , slot_id = 2458851, assembly_id= 2452397;
#
#   BR2.ONOH0.1L3       : BR_ONOH0        , at = 5.467797     , slot_id = 2458849, assembly_id= 2452399;
#
#   BR2.QSKH0.1L3       : BR_QSKH0        , at = 5.467797     , slot_id = 2458850, assembly_id= 2452399;
#
#   BR2.XNOH0.1L3       : BR_XNOH0        , at = 5.467797     , slot_id = 2458852, assembly_id= 2452399;
#
#   BR.QDE1                               , at = 6.234797;
#
#   BI2.KSW1L4          : BR_MKMAG002     , at = 7.001797     , slot_id = 2458863, assembly_id= 5736975;
#
#   BR.QFO12                              , at = 7.580797;
#
#   BR2.BPP1L5          : BR_BPPBA001     , at = 7.997852     , slot_id = 2458842, assembly_id= 2452396;
#
#   BR.STSCRAP12                          , at = 8.199799;
#
#   BR.BHZ12                              , at = 9.008652;
#
# ENDSEQUENCE;
#
#
#
# P02ring2: SEQUENCE, refer = centre, L  = 9.8175; !Ring 2, Period 02
#
#   BR2.BWS.2L1.V_ROT   : BR_BWSV         , at = .918         , slot_id = 2458868, assembly_id= 2452403;
#
#   BR2.BWS.2L1.H_ROT   : BR_BWSH         , at = 1.016        , slot_id = 2458872, assembly_id= 2452403;
#
#   BI2.KSW2L1          : BR_MKMAG002     , at = 1.737        , slot_id = 2458876, assembly_id= 5736984;
#
#   BR.BHZ21                              , at = 3.462849;
#
#   BR.STSCRAP21                          , at = 4.2716995;
#
#   BR.QFO21                              , at = 4.889797;
#
#   BR2.BPM2L3          : BR_UES          , at = 5.467802     , slot_id = 2458891, assembly_id= 2452406;
#
#   BR2.ONOH0.2L3       : BR_ONOH0        , at = 5.467802     , slot_id = 2458889, assembly_id= 2452408;
#
# ...
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/scipy/integrate/_quadpack_py.py:1260: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   quad_r = quad(f, low, high, args=args, full_output=self.full_output,
# ... distance to target bunch length: -9.8998e+00
# ... distance to target bunch length: 1.4070e+01
# ... distance to target bunch length: 1.0223e+01
# ... distance to target bunch length: 6.1652e-01
# ... distance to target bunch length: -6.3193e-02
# ... distance to target bunch length: -5.7318e-04
# ... distance to target bunch length: 8.3483e-09
# ... distance to target bunch length: -5.5011e-05
# --> Bunch length: 10.000000008348254
# --> Emittance: 0.23120048545948796
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/subprocess.py:1127: ResourceWarning: subprocess 1582187 is still running
#   _warn("subprocess %s is still running" % self.pid,
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/site-packages/matplotlib/_api/__init__.py:85: ResourceWarning: unclosed file <_io.FileIO name=75 mode='rb' closefd=True>
#   for k, v in kwargs.items():
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /afs/cern.ch/work/t/tprebiba/python_environments/miniconda3/envs/base-2024/lib/python3.12/multiprocessing/pool.py:268: ResourceWarning: unclosed running multiprocessing pool <multiprocessing.pool.ThreadPool state=RUN pool_size=1>
#   _warn(f"unclosed running multiprocessing pool {self!r}",
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# Text(0, 0.5, 'y [mm]')
